# %%
marks = {}
for _ in range(int(input())):
    line = input().split()
    marks[line[0]] = list(map(float, line[1:]))
print('%.2f' %(sum(marks[input()])/3))
# Out:
# 2
# dhs 49 59 49 40 49
# gth 48 59 90 48 48
# dhs
# 82.00

# %%
if __name__ == '__main__':
    n = int(input())
    student_marks = {}
    for _ in range(n):
        name, *line = input().split()
        scores = list(map(float, line))
        student_marks[name] = scores
    query_name = input()

    queryScore = student_marks[query_name]
    print('{0:.2f}'.format((sum(queryScore))/len(queryScore)))
# Out:
# 2
# sj 48 40 49
# gf 54 59 54
# gf
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-7-2e9161b2c15c> in <module>
#       9     query_name = input()
#      10     query_scores = student_marks[query_name]
# ---> 11     print("%.2f", sum(query_scores)/len(query_scores))
#
# TypeError: object of type 'map' has no len()
